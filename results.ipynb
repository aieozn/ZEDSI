# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec
from Utils import draw_grouped_bar_chart, draw_progress_chart, draw_types_result

# %% [markdown]
# # Wyniki pomiarówi próba optymalizacji parametrów modelu

# %% [markdown]
# # Podejście 1

# %% [markdown]
# #### Podstawowe parametry, wyniki do porównywania skuteczności
# - Convolution 2D size:  3
# - Convolution 2D activation:  relu
# - Pooling 2D size:  5
# - Loss function:  binary_crossentropy
# - Batch size:  100
# - Epochs:  10
# - Dense units:  128

# %%
hamming_loss = 0.15011786892975013
categories_results = [0.7392739273927392, 0.7643564356435644, 0.8798679867986798, 0.9247524752475248, 0.9333333333333333, 0.933993399339934, 0.7735973597359735]
categories_false_positives = [144, 292, 90, 26, 1, 0, 161]
categories_true_negatives = [251, 65, 92, 88, 100, 100, 182]
loss = [0.5615140795707703, 0.49971649050712585, 0.46515700221061707, 0.44854745268821716, 0.4348523020744324, 0.421417772769928, 0.4134643077850342, 0.4014641344547272, 0.39511269330978394, 0.3876998722553253]
val_loss = [0.5301589369773865, 0.47425082325935364, 0.46930867433547974, 0.4478081166744232, 0.42738866806030273, 0.42069822549819946, 0.4153306484222412, 0.4109579920768738, 0.4100881516933441, 0.40564146637916565]
accuracy = [0.2724127173423767, 0.3837684690952301, 0.3488518297672272, 0.35671594738960266, 0.3516829311847687, 0.3463353216648102, 0.3557722568511963, 0.35136836767196655, 0.3413023054599762, 0.3438188135623932]
val_accuracy = [0.4209039509296417, 0.33898305892944336, 0.33898305892944336, 0.38418078422546387, 0.42937853932380676, 0.4124293923377991, 0.39830508828163147, 0.40395480394363403, 0.40395480394363403, 0.395480215549469]
categories = ['loop_scattering', 'background_ring', 'strong_background', 'diffuse_scattering', 'artifact', 'ice_ring', 'non_uniform_detector']

# %%
draw_types_result(categories, categories_results, hamming_loss)

# %%
draw_grouped_bar_chart(categories, categories_false_positives, categories_true_negatives)

# %%
draw_progress_chart(loss, val_loss, accuracy, val_accuracy)

# %% [markdown]
# # Podejście 2 (większy batch, większa ilośc epok)

# %%
hamming_loss = 0.14747760490334746
categories_results = [0.7168316831683168, 0.765016501650165, 0.8759075907590759, 0.9333333333333333, 0.9353135313531353, 0.9346534653465347, 0.8066006600660066]
categories_false_positives = [178, 249, 100, 2, 8, 0, 109]
categories_true_negatives = [251, 107, 88, 99, 90, 99, 184]
loss = [0.6107264161109924, 0.5431522727012634, 0.5227519273757935, 0.4978095293045044, 0.4760952591896057, 0.4620240032672882, 0.45479822158813477, 0.44677507877349854, 0.4388468563556671, 0.4325604736804962, 0.4272679090499878, 0.41966405510902405, 0.4139714241027832, 0.4103519320487976, 0.4081191122531891, 0.4030137062072754, 0.3975090980529785, 0.39362186193466187]
val_loss = [0.5286180973052979, 0.537236750125885, 0.513759434223175, 0.4830314517021179, 0.4786801040172577, 0.46801653504371643, 0.45455843210220337, 0.43901899456977844, 0.4410790801048279, 0.42719966173171997, 0.42924606800079346, 0.4290086627006531, 0.42105430364608765, 0.4126302897930145, 0.4409143924713135, 0.4203682541847229, 0.41353994607925415, 0.4067181646823883]
accuracy = [0.28059136867523193, 0.24536018073558807, 0.4951242506504059, 0.38062283396720886, 0.4114501476287842, 0.3891160786151886, 0.37905001640319824, 0.33501100540161133, 0.36206352710723877, 0.36961308121681213, 0.3570305109024048, 0.366782009601593, 0.35797420144081116, 0.3466498851776123, 0.35514312982559204, 0.3535703122615814, 0.35011008381843567, 0.35262662172317505]
val_accuracy = [0.46045199036598206, 0.44915252923965454, 0.35593220591545105, 0.4717514216899872, 0.4350282549858093, 0.3644067943096161, 0.39830508828163147, 0.443502813577652, 0.4209039509296417, 0.4096045196056366, 0.4406779706478119, 0.41525423526763916, 0.43220338225364685, 0.4350282549858093, 0.46045199036598206, 0.4350282549858093, 0.4265536665916443, 0.41807910799980164]
categories = ['loop_scattering', 'background_ring', 'strong_background', 'diffuse_scattering', 'artifact', 'ice_ring', 'non_uniform_detector']

# %%
draw_types_result(categories, categories_results, hamming_loss)

# %%
draw_grouped_bar_chart(categories, categories_false_positives, categories_true_negatives)

# %%
draw_progress_chart(loss, val_loss, accuracy, val_accuracy)

# %% [markdown]
# # Podejście 4 (większy batch, większa ilośc epok, learning_rate=0.0001)
# Próba usunięcia problemu z accuracy przez zmianę learning rate (nie pomogło)
# - Convolution 2D size:  3
# - Convolution 2D activation:  relu
# - Pooling 2D size:  5
# - Loss function:  binary_crossentropy
# - Batch size:  300
# - Epochs:  18
# - Dense units:  128

# %%
hamming_loss = 0.2261197548326261
categories_results = [0.3405940594059406, 0.7801980198019802, 0.6996699669966997, 0.9306930693069307, 0.9267326732673268, 0.9287128712871288, 0.8105610561056106]
categories_false_positives = [971, 303, 399, 0, 0, 0, 0]
categories_true_negatives = [28, 30, 56, 105, 111, 108, 287]
loss = [0.7803175449371338, 0.6759244203567505, 0.5888078808784485, 0.5482722520828247, 0.539965808391571, 0.536651611328125, 0.534917950630188, 0.5333742499351501, 0.5319288969039917, 0.5302040576934814, 0.5282148122787476, 0.5259695649147034, 0.5234693884849548, 0.5206119418144226, 0.517342746257782, 0.5133808851242065, 0.5090276598930359, 0.5041224956512451]
val_loss = [0.7640129327774048, 0.6493051052093506, 0.567052960395813, 0.534950315952301, 0.5263357758522034, 0.5284960865974426, 0.5309230089187622, 0.5295583605766296, 0.5287491679191589, 0.5271955728530884, 0.5245312452316284, 0.522325336933136, 0.5212215185165405, 0.5181800127029419, 0.5147923231124878, 0.5138627290725708, 0.5102803111076355, 0.5042980909347534]
accuracy = [0.013840830884873867, 0.03208556026220322, 0.24347278475761414, 0.6030198335647583, 0.6030198335647583, 0.4007549583911896, 0.13494808971881866, 0.3227429986000061, 0.3243158161640167, 0.3865995705127716, 0.33815664052963257, 0.35011008381843567, 0.3705567717552185, 0.4101918935775757, 0.37653350830078125, 0.3969801962375641, 0.40452972054481506, 0.3932054042816162]
val_accuracy = [0.0028248587623238564, 0.0451977401971817, 0.46045199036598206, 0.46045199036598206, 0.46045199036598206, 0.0451977401971817, 0.24576270580291748, 0.299435019493103, 0.30790960788726807, 0.2853107452392578, 0.2542372941970825, 0.33898305892944336, 0.35593220591545105, 0.347457617521286, 0.3813559412956238, 0.38418078422546387, 0.3813559412956238, 0.4265536665916443]
categories = ['loop_scattering', 'background_ring', 'strong_background', 'diffuse_scattering', 'artifact', 'ice_ring', 'non_uniform_detector']

# %%
draw_types_result(categories, categories_results, hamming_loss)

# %%
draw_grouped_bar_chart(categories, categories_false_positives, categories_true_negatives)

# %%
draw_progress_chart(loss, val_loss, accuracy, val_accuracy)

# %% [markdown]
# # Podejście 5 (większy batch, większa ilośc epok)
# - Convolution 2D size:  3
# - Convolution 2D activation:  relu
# - Pooling 2D size:  5
# - Loss function:  binary_crossentropy
# - Batch size:  300
# - Epochs:  20
# - Dense units:  128

# %%
hamming_loss = 0.15483262611975485
categories_results = [0.7141914191419142, 0.7511551155115511, 0.8745874587458746, 0.932013201320132, 0.9353135313531353, 0.93003300330033, 0.7788778877887789]
categories_false_positives = [192, 237, 73, 6, 3, 9, 170]
categories_true_negatives = [241, 140, 117, 97, 95, 97, 165]
loss = [0.5741122961044312, 0.535750687122345, 0.5168300867080688, 0.4921075999736786, 0.47414934635162354, 0.4613359570503235, 0.45080551505088806, 0.44513368606567383, 0.43757641315460205, 0.4314916431903839, 0.42631983757019043, 0.421332985162735, 0.4214792549610138, 0.4217813313007355, 0.41471949219703674, 0.4068056046962738, 0.40595394372940063, 0.40340733528137207, 0.395836740732193, 0.39173123240470886]
val_loss = [0.530082643032074, 0.5284261107444763, 0.5028307437896729, 0.48244309425354004, 0.46517568826675415, 0.4486786723136902, 0.4423612654209137, 0.44661951065063477, 0.43000534176826477, 0.42611005902290344, 0.42173102498054504, 0.42446598410606384, 0.46124762296676636, 0.42161762714385986, 0.4166274070739746, 0.41797634959220886, 0.42611339688301086, 0.4292127192020416, 0.41785573959350586, 0.4128137230873108]
accuracy = [0.3038691282272339, 0.41774141788482666, 0.4237181544303894, 0.3865995705127716, 0.3721295893192291, 0.36709657311439514, 0.36174896359443665, 0.366782009601593, 0.3463353216648102, 0.3372129499912262, 0.3488518297672272, 0.3438188135623932, 0.34476250410079956, 0.3284051716327667, 0.32588863372802734, 0.33280906081199646, 0.3362692594528198, 0.3416168689727783, 0.34727901220321655, 0.3343818783760071]
val_accuracy = [0.46045199036598206, 0.43220338225364685, 0.3785310685634613, 0.4124293923377991, 0.43220338225364685, 0.41807910799980164, 0.38418078422546387, 0.41525423526763916, 0.395480215549469, 0.4067796468734741, 0.4124293923377991, 0.4209039509296417, 0.40112993121147156, 0.4406779706478119, 0.4378530979156494, 0.41525423526763916, 0.44632768630981445, 0.44915252923965454, 0.443502813577652, 0.451977401971817]
categories = ['loop_scattering', 'background_ring', 'strong_background', 'diffuse_scattering', 'artifact', 'ice_ring', 'non_uniform_detector']

# %%
draw_types_result(categories, categories_results, hamming_loss)

# %%
draw_grouped_bar_chart(categories, categories_false_positives, categories_true_negatives)

# %%
draw_progress_chart(loss, val_loss, accuracy, val_accuracy)

# %% [markdown]
# # Podejście 6 optymalizacja jedej kategorii (loop scattering)
# Widać wzrost accuracy!
# - Convolution 2D size:  3
# - Convolution 2D activation:  relu
# - Pooling 2D size:  5
# - Loss function:  binary_crossentropy
# - Batch size:  300
# - Epochs:  12
# - Dense units:  128

# %%
hamming_loss = 0.24158415841584158
categories_results = [0.7584158415841584]
categories_false_positives = [75]
categories_true_negatives = [291]
loss = [0.6852362155914307, 0.6706912517547607, 0.6483899354934692, 0.623612642288208, 0.6054836511611938, 0.5820444226264954, 0.5735108256340027, 0.5788041353225708, 0.5793798565864563, 0.5729731917381287, 0.5638037323951721, 0.5603412985801697]
val_loss = [0.7469630837440491, 0.6818689703941345, 0.7217261791229248, 0.631415069103241, 0.6351027488708496, 0.6135125160217285, 0.6638152003288269, 0.6295930743217468, 0.6124232411384583, 0.6153045296669006, 0.6084399223327637, 0.6057354211807251]
accuracy = [0.5671594738960266, 0.5866624712944031, 0.6338471174240112, 0.6536646485328674, 0.6766278743743896, 0.6973891258239746, 0.7061969041824341, 0.6892104148864746, 0.6901541352272034, 0.7024221420288086, 0.7021076083183289, 0.7061969041824341]
val_accuracy = [0.4406779706478119, 0.5197740197181702, 0.4689265489578247, 0.6779661178588867, 0.6412429213523865, 0.6892655491828918, 0.5706214904785156, 0.6610169410705566, 0.6977401375770569, 0.6779661178588867, 0.6920903921127319, 0.6723163723945618]
categories = ['loop_scattering']

# %%
draw_types_result(categories, categories_results, hamming_loss)

# %%
draw_grouped_bar_chart(categories, categories_false_positives, categories_true_negatives)

# %%
draw_progress_chart(loss, val_loss, accuracy, val_accuracy)

# %% [markdown]
# # Podejście 7 categorical cross entrophy
# - Convolution 2D size:  3
# - Convolution 2D activation:  relu
# - Pooling 2D size:  5
# - Loss function:  categorical_crossentropy
# - Batch size:  300
# - Epochs:  12
# - Dense units:  128

# %%
hamming_loss = 0.22706270627062705
categories_results = [0.3425742574257426, 0.7544554455445545, 0.8653465346534653, 0.9306930693069307, 0.93003300330033, 0.9293729372937294, 0.6580858085808581]
categories_false_positives = [964, 283, 107, 0, 11, 1, 371]
categories_true_negatives = [32, 89, 97, 105, 95, 106, 147]
loss = [4.3759026527404785, 4.227199554443359, 4.212797164916992, 4.207182884216309, 4.191346168518066, 4.175482273101807, 4.145393371582031, 4.098280906677246, 4.061768531799316, 4.02615213394165, 3.9742484092712402, 3.929672956466675]
val_loss = [3.7510740756988525, 3.7119898796081543, 3.6914520263671875, 3.691737651824951, 3.66160249710083, 3.653057813644409, 3.599276304244995, 3.5689752101898193, 3.4837870597839355, 3.47190523147583, 3.4300551414489746, 3.3722565174102783]
accuracy = [0.3529411852359772, 0.6030198335647583, 0.6030198335647583, 0.6030198335647583, 0.6030198335647583, 0.6030198335647583, 0.6030198335647583, 0.6030198335647583, 0.6027052402496338, 0.5508021116256714, 0.38188108801841736, 0.3582887649536133]
val_accuracy = [0.46045199036598206, 0.46045199036598206, 0.46045199036598206, 0.46045199036598206, 0.46045199036598206, 0.46045199036598206, 0.46045199036598206, 0.46045199036598206, 0.4971751272678375, 0.46327683329582214, 0.44915252923965454, 0.44632768630981445]
categories = ['loop_scattering', 'background_ring', 'strong_background', 'diffuse_scattering', 'artifact', 'ice_ring', 'non_uniform_detector']

# %%
draw_types_result(categories, categories_results, hamming_loss)

# %%
draw_grouped_bar_chart(categories, categories_false_positives, categories_true_negatives)

# %%
draw_progress_chart(loss, val_loss, accuracy, val_accuracy)

# %% [markdown]
# # Podejście 8 wszystkich kategorii osobno (jeżeli jest poprawa)
# - Convolution 2D size:  3
# - Convolution 2D activation:  relu
# - Pooling 2D size:  5
# - Loss function:  binary_crossentropy
# - Batch size:  300
# - Epochs:  12
# - Dense units:  128

val_accuracy_ice_ring = [0.9124293923377991, 0.9124293923377991, 0.9124293923377991, 0.9124293923377991, 0.9124293923377991, 0.9124293923377991, 0.9124293923377991, 0.9124293923377991, 0.9124293923377991, 0.9124293923377991, 0.9124293923377991, 0.9124293923377991]
loss_non_uniform_detector = [0.6762622594833374, 0.668455958366394, 0.6587579250335693, 0.6483885049819946, 0.635403037071228, 0.6333313584327698, 0.624777615070343, 0.6163839101791382, 0.6171371340751648, 0.6144194006919861, 0.601855456829071, 0.5952397584915161]
accuracy_non_uniform_detector = [0.602390706539154, 0.602390706539154, 0.602390706539154, 0.602390706539154, 0.6077382564544678, 0.6152878403663635, 0.624095618724823, 0.6363636255264282, 0.6351053714752197, 0.6546083688735962, 0.6476879715919495, 0.6615287661552429]
val_loss_non_uniform_detector = [0.6947273015975952, 0.6900556683540344, 0.6789591312408447, 0.6947529911994934, 0.6814958453178406, 0.729516863822937, 0.7328882813453674, 0.730981707572937, 0.6841099858283997, 0.7044922113418579, 0.6907613277435303, 0.690805971622467]
val_accuracy_non_uniform_detector = [0.5790960192680359, 0.5790960192680359, 0.5790960192680359, 0.5790960192680359, 0.5338982939720154, 0.5790960192680359, 0.5819209218025208, 0.5734463334083557, 0.5734463334083557, 0.5564971566200256, 0.5819209218025208, 0.5706214904785156]

# %%
draw_progress_chart(loss_loop_scattering, val_loss_loop_scattering, accuracy_loop_scattering, val_accuracy_loop_scattering, suptitle="Loop scattering")
draw_progress_chart(loss_background_ring, val_loss_background_ring, accuracy_background_ring, val_accuracy_background_ring, suptitle="Background ring")
draw_progress_chart(loss_strong_background, val_loss_strong_background, accuracy_strong_background, val_accuracy_strong_background, suptitle="Strong background")
draw_progress_chart(loss_diffuse_scattering, val_loss_diffuse_scattering, accuracy_diffuse_scattering, val_accuracy_diffuse_scattering, suptitle="Diffuse scattering")
draw_progress_chart(loss_artifact, val_loss_artifact, accuracy_artifact, val_accuracy_artifact, suptitle="Artifact")
draw_progress_chart(loss_ice_ring, val_loss_ice_ring, accuracy_ice_ring, val_accuracy_ice_ring, suptitle="Ice ring")
draw_progress_chart(loss_non_uniform_detector, val_loss_non_uniform_detector, accuracy_non_uniform_detector, val_accuracy_non_uniform_detector, "Non iniform detector")

# %%
draw_types_result(categories, categories_results, hamming_loss)

# %%
draw_grouped_bar_chart(categories, categories_false_positives, categories_true_negatives)

# %% [markdown]
# # Podejście 9 zmniejszenie ilości dense units
# - Convolution 2D size:  3
# - Convolution 2D activation:  relu
# - Pooling 2D size:  5
# - Loss function:  binary_crossentropy
# - Batch size:  300
# - Epochs:  12
# - Dense units:  64

# %%
hamming_loss = 0.17057991513437057
categories_results = [0.5973597359735974, 0.7313531353135313, 0.8805280528052806, 0.9306930693069307, 0.9267326732673268, 0.9287128712871288, 0.8105610561056106]
categories_false_positives = [390, 272, 110, 0, 0, 0, 0]
categories_true_negatives = [220, 135, 71, 105, 111, 108, 287]
loss = [0.677480161190033, 0.5419111847877502, 0.5393927097320557, 0.5355509519577026, 0.5311848521232605, 0.5260295867919922, 0.5203292369842529, 0.5152215361595154, 0.5097398161888123, 0.5062071681022644, 0.5030946731567383, 0.5002467036247253]
val_loss = [0.5520161986351013, 0.5379993915557861, 0.5325224995613098, 0.527256190776825, 0.513912558555603, 0.5170901417732239, 0.5037602782249451, 0.49626195430755615, 0.48893728852272034, 0.4869697391986847, 0.4834630787372589, 0.4840067923069]
accuracy = [0.046555519104003906, 0.07738282531499863, 0.4982698857784271, 0.45202893018722534, 0.29663416743278503, 0.15665303170681, 0.24944950640201569, 0.31676629185676575, 0.30449825525283813, 0.2761874794960022, 0.2692670524120331, 0.24913494288921356]
val_accuracy = [0.0451977401971817, 0.0451977401971817, 0.46045199036598206, 0.0451977401971817, 0.28248587250709534, 0.2118644118309021, 0.5, 0.4576271176338196, 0.395480215549469, 0.3785310685634613, 0.39830508828163147, 0.37005650997161865]
categories = ['loop_scattering', 'background_ring', 'strong_background', 'diffuse_scattering', 'artifact', 'ice_ring', 'non_uniform_detector']

# %%
draw_types_result(categories, categories_results, hamming_loss)

# %%
draw_grouped_bar_chart(categories, categories_false_positives, categories_true_negatives)

# %%
draw_progress_chart(loss, val_loss, accuracy, val_accuracy)

# %% [markdown]
# # Podejście 10 zwiększenie ilości dense units
# - Convolution 2D size:  3
# - Convolution 2D activation:  relu
# - Pooling 2D size:  5
# - Loss function:  binary_crossentropy
# - Batch size:  300
# - Epochs:  12
# - Dense units:  512

# %%
hamming_loss = 0.15351249410655352
categories_results = [0.766996699669967, 0.695049504950495, 0.8567656765676568, 0.9313531353135314, 0.9346534653465347, 0.9306930693069307, 0.80990099009901]
categories_false_positives = [74, 172, 75, 7, 3, 0, 80]
categories_true_negatives = [279, 290, 142, 97, 96, 105, 208]
loss = [0.5795139670372009, 0.5320208072662354, 0.504524290561676, 0.4819880425930023, 0.46859464049339294, 0.4559871554374695, 0.4466315507888794, 0.4394039809703827, 0.4300066828727722, 0.4240662455558777, 0.4159435033798218, 0.41397973895072937]
val_loss = [0.5490193367004395, 0.5298767685890198, 0.4966234862804413, 0.48679304122924805, 0.4636409282684326, 0.4650336802005768, 0.45550259947776794, 0.4330931007862091, 0.43356797099113464, 0.4224318265914917, 0.4255220293998718, 0.4232547879219055]
accuracy = [0.3309216797351837, 0.4677571654319763, 0.3903743326663971, 0.4007549583911896, 0.37244415283203125, 0.3705567717552185, 0.36741113662719727, 0.364265501499176, 0.3705567717552185, 0.35419943928718567, 0.3545140027999878, 0.35105380415916443]
val_accuracy = [0.21751412749290466, 0.22033898532390594, 0.43220338225364685, 0.395480215549469, 0.44915252923965454, 0.3926553726196289, 0.41525423526763916, 0.41807910799980164, 0.4124293923377991, 0.4265536665916443, 0.42937853932380676, 0.4067796468734741]
categories = ['loop_scattering', 'background_ring', 'strong_background', 'diffuse_scattering', 'artifact', 'ice_ring', 'non_uniform_detector']

# %%
draw_types_result(categories, categories_results, hamming_loss)

# %%
draw_grouped_bar_chart(categories, categories_false_positives, categories_true_negatives)

# %%
draw_progress_chart(loss, val_loss, accuracy, val_accuracy)

# %%
draw_progress_chart(loss, val_loss, accuracy, val_accuracy)

# %%
# draw_types_result(categories, categories_results, hamming_loss)
# draw_grouped_bar_chart(categories, categories_false_positives, categories_true_negatives)
# draw_progress_chart(loss, val_loss, accuracy, val_accuracy)
